# %%
from glove_word_embeddings import pre, val, cat, mod
assert pre.lemmatize("dogs") == "dog"
assert val.noun("dog") is True
assert "animals" in cat.check_bucket("dog")
assert cat.category_chain("dog")[-1] == "dog"
assert cat.check_same_category("dog", "wolf") is True
m = mod.load("glove-6b-300d")
assert m.embed_exact("dog") is not None
assert isinstance(m.vocab_set(), set)
